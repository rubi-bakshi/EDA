# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("Attribute+DataSet.csv")
inp1= pd.read_csv("Dress+Sales.csv")
inp0.head(10)
#print('\n')
#inp1.head(10)
# Out:
#      Dress_ID     Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 0  1006032852      Sexy      Low     4.6     M  Summer   o-neck    sleevless
# 1  1212192089    Casual      Low     0.0     L  Summer   o-neck        Petal
# 2  1190380701   vintage     High     0.0     L  Automn   o-neck         full
# 3   966005983     Brief  Average     4.6     L  Spring   o-neck         full
# 4   876339541      cute      Low     4.5     M  Summer   o-neck    butterfly
# 5  1068332458  bohemian      Low     0.0     M  Summer   v-neck    sleevless
# 6  1220707172    Casual  Average     0.0    XL  Summer   o-neck         full
# 7  1113094204     Flare  Average     0.0  free  Spring   v-neck        short
# 8   985292672  bohemian      Low     0.0  free  Summer   v-neck    sleevless
# 9  1117293701     party  Average     5.0  free  Summer   o-neck         full
#
#         Material  FabricType  Decoration Pattern Type  Recommendation
# ...

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.
inp0.info()
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
# ...

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Print the value counts of each category in "Size" column.
inp0.Size.value_counts()
# Out:
# M        171
# free     165
# L         93
# S         34
# XL        14
# small      1
# s          1
# Name: Size, dtype: int64

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
inp0.Size.replace({'M':"Medium",'L':"Large",'s':"Small",'S':"Small",'small':"Small",'XL':"Extra Large",'free':"Free"}, inplace = True)
inp0.head(10)
# Out:
#      Dress_ID     Style    Price  Rating         Size  Season NeckLine  \
# 0  1006032852      Sexy      Low     4.6       Medium  Summer   o-neck
# 1  1212192089    Casual      Low     0.0        Large  Summer   o-neck
# 2  1190380701   vintage     High     0.0        Large  Automn   o-neck
# 3   966005983     Brief  Average     4.6        Large  Spring   o-neck
# 4   876339541      cute      Low     4.5       Medium  Summer   o-neck
# 5  1068332458  bohemian      Low     0.0       Medium  Summer   v-neck
# 6  1220707172    Casual  Average     0.0  Extra Large  Summer   o-neck
# 7  1113094204     Flare  Average     0.0         Free  Spring   v-neck
# 8   985292672  bohemian      Low     0.0         Free  Summer   v-neck
# 9  1117293701     party  Average     5.0         Free  Summer   o-neck
#
#   SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0    sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
# Print the value counts of each category in "Size" column.
inp0.Size.value_counts()
# Out:
# Medium         171
# Free           165
# Large           93
# Small           36
# Extra Large     14
# Name: Size, dtype: int64

# %%
#Print the value counts of each category in "Size" column in %.
inp0.Size.value_counts(normalize=True)* 100
# Out:
# Medium         35.699374
# Free           34.446764
# Large          19.415449
# Small           7.515658
# Extra Large     2.922756
# Name: Size, dtype: float64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
print(inp0.isnull().sum())
print(inp0.shape)
print('\n')
print(inp1.isnull().sum())
print(inp1.shape)
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64
# (479, 13)
#
#
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64
# (479, 24)

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.info()
inp1.head(10)
#inp1.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
#print(inp1["22-09-2013"].dtypes)

inp1.loc[inp1['09-12-2013']== 'Removed', "09-12-2013"]= np.NaN
inp1.loc[inp1['14-09-2013']=='removed', '14-09-2013']= np.NaN
inp1.loc[inp1['16-09-2013']=='removed','16-09-2013']=np.NaN
inp1.loc[inp1['18-09-2013']=='removed','18-09-2013']=np.NaN
inp1.loc[inp1['20-09-2013']=='removed','20-09-2013']=np.NaN
inp1.loc[inp1['22-09-2013']=='Orders','22-09-2013']=np.NaN

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1["09-12-2013"]=inp1['09-12-2013'].astype(float)
inp1['14-09-2013']=inp1['14-09-2013'].astype(float)
inp1['16-09-2013']=inp1['16-09-2013'].astype(float)
inp1['18-09-2013']=inp1['18-09-2013'].astype(float)
inp1['20-09-2013']=inp1['20-09-2013'].astype(float)
inp1['22-09-2013']=inp1['22-09-2013'].astype(float)

#print(inp1["22-09-2013"].dtypes)

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
inp1.isnull().sum() *100/ len(inp1)
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.208768
# 14-09-2013     0.208768
# 16-09-2013     0.208768
# 18-09-2013     0.208768
# 20-09-2013     0.208768
# 22-09-2013     0.208768
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
# Print the columns in "Dress Sales" which have more than 40% of missing values.
(inp1.isnull().sum()/len(inp1)*100>40.0)[:]
# Out:
# Dress_ID      False
# 29-08-2013    False
# 31-08-2013    False
# 09-02-2013    False
# 09-04-2013    False
# 09-06-2013    False
# 09-08-2013    False
# 09-10-2013    False
# 09-12-2013    False
# 14-09-2013    False
# 16-09-2013    False
# 18-09-2013    False
# 20-09-2013    False
# 22-09-2013    False
# 24-09-2013    False
# 26-09-2013     True
# 28-09-2013    False
# 30-09-2013     True
# 10-02-2013     True
# 10-04-2013     True
# 10-06-2013    False
# 10-08-2013     True
# 10-10-2013     True
# 10-12-2013    False
# dtype: bool

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1.drop(columns=['26-09-2013','30-09-2013','10-02-2013','10-04-2013','10-08-2013','10-10-2013'], inplace=True)

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  28-09-2013  479 non-null    int64
#  16  10-06-2013  479 non-null    int64
#  17  10-12-2013  479 non-null    int64
# dtypes: float64(7), int64(11)
# ...

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
inp0.Season.value_counts()
# Out:
# Summer    154
# Spring    116
# Winter     94
# Automn     59
# winter     45
# Autumn      7
# spring      2
# Name: Season, dtype: int64

# %%
inp1.columns
# Out:
# Index(['Dress_ID', '29-08-2013', '31-08-2013', '09-02-2013', '09-04-2013',
#        '09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013', '14-09-2013',
#        '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013',
#        '28-09-2013', '10-06-2013', '10-12-2013'],
#       dtype='object')

# %%
# Create the four seasons columns in inp1, according to the above criteria.
inp1['Summer'] = inp1['09-06-2013'] + inp1['10-06-2013'] + inp1['29-08-2013'] + inp1['31-08-2013'] + inp1['09-08-2013']
inp1['Autumn'] = inp1['09-10-2013'] + inp1['14-09-2013'] + inp1['16-09-2013'] + inp1['18-09-2013'] + inp1['20-09-2013'] + inp1['22-09-2013'] + inp1['24-09-2013'] + inp1['28-09-2013']
inp1['Winter'] = inp1['09-12-2013'] + inp1['10-12-2013'] + inp1['09-02-2013']
inp1['Spring'] = inp1['09-04-2013']

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
inp1[['Summer','Autumn','Winter','Spring']].sum()
# Out:
# Summer     691907.0
# Autumn    1353543.0
# Winter     473640.0
# Spring     143600.0
# dtype: float64

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Summer   Autumn  Winter  Spring
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
inp0.head(10)
# Out:
# /Users/rubi.bakshi/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1183: UserWarning: Parsing '29-08-2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return self._get_slice_axis(key, axis=axis)
#      Dress_ID     Style    Price  Rating         Size  Season NeckLine  \
# 0  1006032852      Sexy      Low     4.6       Medium  Summer   o-neck
# 1  1212192089    Casual      Low     0.0        Large  Summer   o-neck
# 2  1190380701   vintage     High     0.0        Large  Automn   o-neck
# 3   966005983     Brief  Average     4.6        Large  Spring   o-neck
# 4   876339541      cute      Low     4.5       Medium  Summer   o-neck
# 5  1068332458  bohemian      Low     0.0       Medium  Summer   v-neck
# 6  1220707172    Casual  Average     0.0  Extra Large  Summer   o-neck
# 7  1113094204     Flare  Average     0.0         Free  Spring   v-neck
# ...

# %%
#inp0.drop(columns=['20-09-2013','22-09-2013','24-09-2013','28-09-2013','10-06-2013','10-12-2013'],inplace=True)

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Summer              0
# Autumn              2
# Winter              1
# Spring              0
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0.Material = inp0.Material.replace(np.NaN, "Missing")
inp0.FabricType = inp0.FabricType.replace(np.NaN, "Missing")
inp0.Decoration = inp0.Decoration.replace(np.NaN, "Missing")
#inp0.Pattern Type  = inp0.Pattern Type .replace(np.NaN, "Missing")

# %%
inp0.head(10)
# Out:
#      Dress_ID     Style    Price  Rating         Size  Season NeckLine  \
# 0  1006032852      Sexy      Low     4.6       Medium  Summer   o-neck
# 1  1212192089    Casual      Low     0.0        Large  Summer   o-neck
# 2  1190380701   vintage     High     0.0        Large  Automn   o-neck
# 3   966005983     Brief  Average     4.6        Large  Spring   o-neck
# 4   876339541      cute      Low     4.5       Medium  Summer   o-neck
# 5  1068332458  bohemian      Low     0.0       Medium  Summer   v-neck
# 6  1220707172    Casual  Average     0.0  Extra Large  Summer   o-neck
# 7  1113094204     Flare  Average     0.0         Free  Spring   v-neck
# 8   985292672  bohemian      Low     0.0         Free  Summer   v-neck
# 9  1117293701     party  Average     5.0         Free  Summer   o-neck
#
#   SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0    sleevless        Missing     chiffon     ruffles       animal
# ...

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings for columnn 'Season'
inp0.Season.value_counts()
# Out:
# Summer    154
# Spring    116
# Winter     94
# Automn     59
# winter     45
# Autumn      7
# spring      2
# Name: Season, dtype: int64

# %%
inp0.Season.replace({'winter': "Winter",'Automn':"Autumn", "spring": "Spring"}, inplace = True)
inp0.head(10)
# Out:
#      Dress_ID     Style    Price  Rating         Size  Season NeckLine  \
# 0  1006032852      Sexy      Low     4.6       Medium  Summer   o-neck
# 1  1212192089    Casual      Low     0.0        Large  Summer   o-neck
# 2  1190380701   vintage     High     0.0        Large  Autumn   o-neck
# 3   966005983     Brief  Average     4.6        Large  Spring   o-neck
# 4   876339541      cute      Low     4.5       Medium  Summer   o-neck
# 5  1068332458  bohemian      Low     0.0       Medium  Summer   v-neck
# 6  1220707172    Casual  Average     0.0  Extra Large  Summer   o-neck
# 7  1113094204     Flare  Average     0.0         Free  Spring   v-neck
# 8   985292672  bohemian      Low     0.0         Free  Summer   v-neck
# 9  1117293701     party  Average     5.0         Free  Summer   o-neck
#
#   SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0    sleevless        Missing     chiffon     ruffles       animal
# ...

# %%
#correcting the Spellings for column 'Neckline'
inp0.NeckLine.value_counts()
# Out:
# o-neck             257
# v-neck             119
# slash-neck          25
# boat-neck           18
# Sweetheart          14
# turndowncollor      13
# bowneck             10
# peterpan-collor      5
# sqare-collor         5
# open                 3
# Scoop                2
# ruffled              1
# mandarin-collor      1
# sweetheart           1
# halter               1
# backless             1
# Name: NeckLine, dtype: int64

# %%
inp0.NeckLine.replace({'sweetheart': "Sweetheart"}, inplace = True)
inp0.NeckLine.value_counts()
# Out:
# o-neck             257
# v-neck             119
# slash-neck          25
# boat-neck           18
# Sweetheart          15
# turndowncollor      13
# bowneck             10
# peterpan-collor      5
# sqare-collor         5
# open                 3
# Scoop                2
# ruffled              1
# mandarin-collor      1
# halter               1
# backless             1
# Name: NeckLine, dtype: int64

# %%
#correcting the Spellings for column 'Material'  & 'SleeveLength'
inp0.Material.replace({'shiffon': "chiffonfabric",'model': "modal", 'sill': "silk"}, inplace = True)
inp0.Material.value_counts()  
inp0.SleeveLength.replace({'sleevless': "sleeveless",'sleeevless': "sleeveless", 'sleveless': "sleeveless",'thressqatar': "threequarter",'threequater': "threequarter",'capsleeves': "cap-sleeves",'urndowncollor': "turndowncollor"}, inplace = True)
inp0.SleeveLength.value_counts()
# Out:
# sleeveless        223
# full               94
# short              92
# halfsleeve         32
# threequarter       26
# cap-sleeves         5
# turndowncollor      2
# Petal               1
# butterfly           1
# half                1
# Name: SleeveLength, dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
inp0.Season.value_counts()
inp0['Total_sales_allSeason'] = inp0['Summer']+inp0['Spring']+inp0['Winter']+inp0['Autumn']
inp0.head(40)
# Out:
#       Dress_ID     Style    Price  Rating         Size  Season  \
# 0   1006032852      Sexy      Low     4.6       Medium  Summer
# 1   1212192089    Casual      Low     0.0        Large  Summer
# 2   1190380701   vintage     High     0.0        Large  Autumn
# 3    966005983     Brief  Average     4.6        Large  Spring
# 4    876339541      cute      Low     4.5       Medium  Summer
# 5   1068332458  bohemian      Low     0.0       Medium  Summer
# 6   1220707172    Casual  Average     0.0  Extra Large  Summer
# 7   1113094204     Flare  Average     0.0         Free  Spring
# 8    985292672  bohemian      Low     0.0         Free  Summer
# 9   1117293701     party  Average     5.0         Free  Summer
# 10   898481530     Flare  Average     0.0         Free  Spring
# 11   957723897      sexy      Low     4.7       Medium  Winter
# 12   749031896   vintage  Average     4.8       Medium  Summer
# 13  1055411544    Casual      Low     5.0       Medium  Summer
# ...

# %%
style_grouped = inp0.groupby(inp0['Style'])
style_grouped['Total_sales_allSeason'].sum()
# Out:
# Style
# Brief        139628.0
# Casual      1105728.0
# Flare          2089.0
# Novelty       13286.0
# OL              289.0
# Sexy         452794.0
# bohemian      69117.0
# cute         371044.0
# fashion         395.0
# party        147578.0
# sexy          77443.0
# vintage      180574.0
# work          93095.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0['Style']  = inp0['Style'].apply(lambda x: 'Others' if style_grouped.get_group(x)['Total_sales_allSeason'].sum()<50000 else x)

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
inp0.Style.value_counts(normalize=True)*100
# Out:
# Casual      45.720251
# Sexy        13.778706
# party       10.647182
# cute         9.185804
# vintage      5.219207
# bohemian     4.801670
# Brief        3.549061
# work         3.549061
# Others       2.087683
# sexy         1.461378
# Name: Style, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
Neckline_grouped=inp0.groupby(['NeckLine'])
Neckline_grouped.sum()['Total_sales_allSeason']
# Out:
# NeckLine
# Scoop                 3135.0
# Sweetheart           18961.0
# backless              2888.0
# boat-neck            53049.0
# bowneck              21633.0
# halter                2355.0
# mandarin-collor        289.0
# o-neck             1675132.0
# open                  7396.0
# peterpan-collor      18908.0
# ruffled             118871.0
# slash-neck           68396.0
# sqare-collor         32395.0
# turndowncollor       68496.0
# v-neck              550079.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0.replace(Neckline_grouped.sum()[Neckline_grouped.sum().Total_sales_allSeason<50000].index, 'Others', inplace=True)

# %%
inp0.NeckLine.value_counts()
# Out:
# o-neck            257
# v-neck            119
# Others             43
# slash-neck         25
# boat-neck          18
# turndowncollor     13
# ruffled             1
# Name: NeckLine, dtype: int64

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.

SleeveLength_grouped = inp0.groupby(['SleeveLength'])
SleeveLength_grouped.sum()['Total_sales_allSeason']
# Out:
# SleeveLength
# Petal              30682.0
# butterfly          29456.0
# cap-sleeves        13603.0
# full              455632.0
# half                 373.0
# halfsleeve        207470.0
# short             696130.0
# sleeveless        973104.0
# threequarter      233543.0
# turndowncollor      3583.0
# Name: Total_sales_allSeason, dtype: float64

# %%
#inp0.replace(inp0.groupby(inp0.SleeveLength).sum()[(inp0.groupby(inp0.SleeveLength).sum()).total_sales_allSeason<25000].index,'Others',inplace=True)
inp0.replace(SleeveLength_grouped.sum()[SleeveLength_grouped.sum().Total_sales_allSeason<25000].index, 'Others', inplace=True)
inp0.SleeveLength.value_counts()
# Out:
# sleeveless      223
# full             94
# short            92
# halfsleeve       32
# threequarter     26
# Others            8
# Petal             1
# butterfly         1
# Name: SleeveLength, dtype: int64

# %%
#sleeve_group = inp0['total_sales_allSeason'].groupby(inp0['SleeveLength']).sum().reset_index()
#res = sleeve_group.loc[sleeve_group['total_sales_allSeason']<50000]
#res

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
material_grouped = inp0.groupby(['Material'])
material_grouped.sum()['Total_sales_allSeason']
# Out:
# Material
# Missing          668749.0
# acrylic           12155.0
# cashmere           5667.0
# chiffonfabric    341579.0
# cotton           739071.0
# lace               6296.0
# linen             20149.0
# lycra             12555.0
# microfiber        31817.0
# milksilk          33710.0
# mix               68490.0
# modal               767.0
# nylon             29483.0
# other              5458.0
# polyster         487879.0
# rayon             65208.0
# silk              96586.0
# spandex           22402.0
# viscos             4180.0
# wool                859.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0.replace(material_grouped.sum()[material_grouped.sum().Total_sales_allSeason<25000].index, 'Others', inplace=True)
inp0.Material.value_counts(normalize=True)*100
# Out:
# cotton           30.897704
# Missing          24.843424
# polyster         19.415449
# silk              5.636743
# chiffonfabric     5.427975
# Others            5.427975
# mix               2.505219
# nylon             2.087683
# rayon             2.087683
# milksilk          1.043841
# microfiber        0.626305
# Name: Material, dtype: float64

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
FabricType_grouped = inp0.groupby(['FabricType'])
FabricType_grouped.sum()['Total_sales_allSeason']
# Out:
# FabricType
# Corduroy        10866.0
# Missing       1226093.0
# Others           3333.0
# batik            4021.0
# broadcloth     119998.0
# chiffon       1008205.0
# dobby            2761.0
# flannael         6835.0
# flannel         14733.0
# jersey         119952.0
# knitted            14.0
# knitting           39.0
# organza           762.0
# poplin           1443.0
# satin           11403.0
# sattin           9673.0
# shiffon         27486.0
# terry             373.0
# tulle            2119.0
# wollen           2858.0
# woolen              0.0
# worsted         80093.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0.replace(FabricType_grouped.sum()[FabricType_grouped.sum().Total_sales_allSeason<25000].index,'Others', inplace=True)
inp0.FabricType.value_counts(normalize=True)*100
# Out:
# Missing       53.444676
# chiffon       26.931106
# broadcloth     6.054280
# Others         5.636743
# worsted        3.757829
# jersey         2.505219
# shiffon        1.670146
# Name: FabricType, dtype: float64

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
patternType_grouped = inp0.groupby(['Pattern Type'])
patternType_grouped.sum()['Total_sales_allSeason']
# Out:
# Pattern Type
# animal        211273.0
# character       3738.0
# dot           245091.0
# floral         10614.0
# geometric     114335.0
# leapord         3017.0
# leopard        25267.0
# none            5991.0
# patchwork     190498.0
# plaid           1369.0
# print         403025.0
# solid        1118127.0
# splice          5112.0
# striped        61945.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0.replace(patternType_grouped.sum()[patternType_grouped.sum().Total_sales_allSeason<25000].index,'Others', inplace = True)

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
decoration_grouped = inp0.groupby(['Decoration'])
decoration_grouped.sum()['Total_sales_allSeason']
# Out:
# Decoration
# Missing       1095689.0
# Others         428578.0
# Tiered          22147.0
# applique        67873.0
# beading         48911.0
# bow            255359.0
# button          22203.0
# cascading         210.0
# crystal          6450.0
# draped           7099.0
# embroidary      45760.0
# feathers           64.0
# flowers          6676.0
# hollowout       67758.0
# pearls             41.0
# plain            2740.0
# pleat            1645.0
# pockets         21532.0
# rivet           17801.0
# ruched           7940.0
# ruffles        191187.0
# sashes         285759.0
# sequined        48699.0
# tassel            939.0
# Name: Total_sales_allSeason, dtype: float64

# %%
inp0.replace(decoration_grouped.sum()[decoration_grouped.sum().Total_sales_allSeason<25000].index,'Others', inplace=True)
inp0.Decoration.value_counts(normalize=True)*100
# Out:
# Missing       46.764092
# Others        21.294363
# sashes         8.559499
# beading        4.592902
# hollowout      4.384134
# applique       4.175365
# ruffles        3.549061
# bow            2.922756
# sequined       2.713987
# embroidary     1.043841
# Name: Decoration, dtype: float64

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
inp0['Autumn'].describe()
#OR
#inp0.Autumn.describe()
# Out:
# count      477.000000
# mean      2837.616352
# std       5010.790796
# min          1.000000
# 25%        406.000000
# 50%       1329.000000
# 75%       3122.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
diffMax_Percentile= inp0['Autumn'].max()-inp0['Autumn'].quantile(0.75)
diffMax_Percentile
# Out:
# 52410.0

# %%
# plot the boxplot of "Autumn" column.
sns.boxplot(inp0.Autumn)
plt.show()
# Out:
# /Users/rubi.bakshi/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
NinetyninePercentile = inp0['Winter'].quantile(0.99)
Max_Sale = inp0['Winter'].max()
diff_inSales = Max_Sale-NinetyninePercentile
print(diff_inSales)

inp0['Winter'].describe()
# Out:
# 11469.969999999983
# count      478.000000
# mean       990.878661
# std       1851.691244
# min          0.000000
# 25%        122.000000
# 50%        400.000000
# 75%       1097.000000
# max      20388.000000
# Name: Winter, dtype: float64

# %%
# Find the maximum and 99th percentile of Summer season.
NinetyninePercentile = inp0['Summer'].quantile(0.99)
Max_Sale = inp0['Summer'].max()
diff_inSales = Max_Sale-NinetyninePercentile
print(diffMax_Percentile)
print(Max_Sale)
print(diff_inSales)

inp0['Summer'].describe()
# Out:
# 52410.0
# 35577
# 21623.000000000007
# count      479.000000
# mean      1444.482255
# std       2976.993959
# min          2.000000
# 25%        156.500000
# 50%        518.000000
# 75%       1475.500000
# max      35577.000000
# Name: Summer, dtype: float64

# %%
# Find the maximum and 99th percentile of Spring season.
print(inp0.Spring.max())
print(inp0.Spring.quantile(0.99))
diff_Spring = inp0.Spring.max()-inp0.Spring.quantile(0.99)
diff_Spring
# Out:
# 7374
# 2656.88
# 4717.12

# %%
# Find the maximum and 99th percentile of Autumn season.
print(inp0.Autumn.max())
print(inp0.Autumn.quantile(0.99))
diff_Autumn = inp0.Autumn.max()-inp0.Autumn.quantile(0.99)
diff_Autumn
# Out:
# 55532.0
# 24003.80000000002
# 31528.19999999998

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
inp0.groupby('Price')['Rating'].mean()  
#OR
#inp0['Rating'].groupby(inp0['Price']).mean()
# Out:
# Price
# Average      3.464167
# High         2.914286
# Low          3.692121
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
inp0.groupby('Style')['Rating'].median()
# Out:
# Style
# Brief       4.60
# Casual      4.60
# Others      0.00
# Sexy        4.55
# bohemian    4.60
# cute        4.55
# party       4.70
# sexy        4.50
# vintage     4.60
# work        4.70
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck   sleeveless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Summer  \
# 0        Missing    chiffon     ruffles       animal               1   13899
# 1     microfiber    Missing     ruffles       animal               0    6216
# 2       polyster    Missing     Missing        print               0      40
# 3           silk    chiffon  embroidary        print               1    7213
# 4  chiffonfabric    chiffon         bow          dot               0    7706
#
# ...

# %%
# Summer sale vs Recommendation.
inp0.groupby('Recommendation')['Summer'].mean()
# Out:
# Recommendation
# 0    1430.149635
# 1    1463.639024
# Name: Summer, dtype: float64

# %%
sns.boxplot(data=inp0, x='Recommendation', y='Summer')
plt.show()

# %%
# Spring sale vs Recommendation.
inp0.groupby('Recommendation')['Spring'].mean()
# Out:
# Recommendation
# 0    298.051095
# 1    302.117073
# Name: Spring, dtype: float64

# %%
sns.boxplot(data=inp0, x= 'Recommendation', y = 'Spring')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Autumn sale vs Recommendation.
inp0.groupby('Recommendation')['Autumn'].mean()
# Out:
# Recommendation
# 0    2840.193431
# 1    2834.137931
# Name: Autumn, dtype: float64

# %%
sns.boxplot(data=inp0, x='Recommendation', y='Autumn')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Winter sale vs Recommendation.
inp0.groupby('Recommendation')['Winter'].mean()
# Out:
# Recommendation
# 0    985.660584
# 1    997.887255
# Name: Winter, dtype: float64

# %%
sns.boxplot(data=inp0, x='Recommendation', y='Winter')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
inp0.groupby('Size')['Recommendation'].sum()
# Out:
# Size
# Extra Large     4
# Free           76
# Large          36
# Medium         76
# Small          13
# Name: Recommendation, dtype: int64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
hm_SPR = pd.pivot_table(data=inp0, index='Style', columns='Price', values = 'Recommendation')
hm_SPR
# Out:
# Price      Average      High       Low    Medium  very-high
# Style
# Brief     0.333333       NaN  0.000000       NaN        NaN
# Casual    0.345455  0.666667  0.382022  0.666667   0.500000
# Others    0.375000       NaN       NaN  0.500000        NaN
# Sexy      0.344828  0.000000  0.515152  0.000000   0.000000
# bohemian  0.333333       NaN  0.666667  1.000000   1.000000
# cute      0.380952  0.666667  0.500000  1.000000        NaN
# party     0.666667  0.333333       NaN  0.800000   0.823529
# sexy      0.500000       NaN  0.750000  0.000000        NaN
# vintage   0.352941  0.000000  0.250000  0.500000        NaN
# work      0.214286       NaN  0.000000  0.000000        NaN

# %%
sns.heatmap(hm_SPR, cmap='RdYlGn', annot=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Style'>

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
hm_smr = pd.pivot_table(data=inp0, index='Material', columns= 'Season', values ='Recommendation')
hm_smr
# Out:
# Season           Autumn    Spring    Summer    Winter
# Material
# Missing        0.428571  0.657143  0.470588  0.500000
# Others         0.000000  0.500000  0.166667  0.400000
# chiffonfabric  0.500000  0.583333  0.125000  0.000000
# cotton         0.294118  0.576923  0.386667  0.517241
# microfiber          NaN  1.000000  0.000000  0.000000
# milksilk       1.000000       NaN  0.000000  0.000000
# mix                 NaN  0.500000  0.333333  0.200000
# nylon          0.000000  0.333333  1.000000  0.333333
# polyster       0.266667  0.571429  0.071429  0.360000
# rayon          0.666667  1.000000  0.333333       NaN
# silk           0.000000  0.538462  0.000000  0.714286

# %%
sns.heatmap(hm_smr[['Summer','Winter']], cmap='RdYlGn', annot=True)
# Out:
# <AxesSubplot:xlabel='Season', ylabel='Material'>
